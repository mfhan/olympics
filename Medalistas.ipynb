# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
season = 'Summer'

# %%
athlete_orig = pd.read_csv('Olympic_Athlete_Event_Results.csv')
athlete_orig.head(5)
# Out:
#                 edition  edition_id country_noc      sport            event  \
# 0  1908 Summer Olympics           5         ANZ  Athletics  100 metres, Men
# 1  1908 Summer Olympics           5         ANZ  Athletics  400 metres, Men
# 2  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 3  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
# 4  1908 Summer Olympics           5         ANZ  Athletics  800 metres, Men
#
#    result_id          athlete  athlete_id        pos medal  isTeamSport
# 0      56265  Ernest Hutcheon       64710        DNS    na        False
# 1      56313     Henry Murray       64756        DNS    na        False
# 2      56338    Harvey Sutton       64808  3 h8 r1/2    na        False
# 3      56338      Guy Haskins      922519        DNS    na        False
# 4      56338     Joseph Lynch       64735        DNS    na        False

# %%
athlete_df = pd.read_csv('Olympic_Athlete_Event_Results.csv', usecols=['edition', 'athlete', 'athlete_id', 'medal'])
athlete_df[['year', 'season']] = athlete_df['edition'].str.split(' ', expand=True, n=1)
athlete_df['year'] = athlete_df['year'].astype(int)
# Remove "Olympics" from "Summer/Winter Olympics"
athlete_df['season'] = athlete_df['season'].str.split(' ', n=1).str[0]

# %%
# rename the column to be uniform with the DataFrame we will merge with later
# not necessary, but helpful to simplify our data
athlete_df = athlete_df.rename(columns={'athlete': 'name'})
athlete_df = athlete_df[athlete_df['season'] == season]

athlete_df.head(8)
# Out:
#                 edition             name  athlete_id medal  year  season
# 0  1908 Summer Olympics  Ernest Hutcheon       64710    na  1908  Summer
# 1  1908 Summer Olympics     Henry Murray       64756    na  1908  Summer
# 2  1908 Summer Olympics    Harvey Sutton       64808    na  1908  Summer
# 3  1908 Summer Olympics      Guy Haskins      922519    na  1908  Summer
# 4  1908 Summer Olympics     Joseph Lynch       64735    na  1908  Summer
# 5  1908 Summer Olympics     Henry Murray       64756    na  1908  Summer
# 6  1908 Summer Olympics     Joseph Lynch       64735    na  1908  Summer
# 7  1908 Summer Olympics    Charles Swain       79576    na  1908  Summer

# %%
bio_df = pd.read_csv('Olympic_Athlete_Bio.csv')
bio_df.shape
# Out:
# (155031, 10)

# %%
bio_df.head(8)
# Out:
#    athlete_id                 name     sex        born height weight  \
# 0       16809       Károly Teppert    Male  1891-07-20     na     na
# 1       43737    Andrzej Socharski    Male  1947-08-31  173.0     72
# 2       50147  Nathalie Wunderlich  Female  1971-06-03  170.0     50
# 3        5085           Miha Lokar    Male  1935-09-10  182.0     76
# 4      136329          Austin Hack    Male  1992-05-17  203.0    100
# 5       38633     Tsuneo Ogasawara    Male  1942-07-30  181.0     80
# 6       24791          Saad Rashed    Male  1928-11-20     na     na
# 7       77095       Fulgence Rwabu    Male  1947-11-23  165.0     51
#
#           country country_noc  \
# 0         Hungary         HUN
# 1          Poland         POL
# 2     Switzerland         SUI
# 3      Yugoslavia         YUG
# 4   United States         USA
# 5           Japan         JPN
# 6           Egypt         EGY
# 7          Uganda         UGA
#
#                                          description  \
# 0  Károly Teppert started competing in cycling in...
# 1                                                 na
# 2                                                 na
# 3                                                 na
# 4                                                 na
# 5                                                 na
# 6                                                 na
# 7                      Personal Best: Mar – unknown.
#
#                                        special_notes
# 0                                                 na
# 1  Listed in Olympians Who Won a Medal at the Wor...
# 2                                                 na
# 3  Listed in Olympians Who Won a Medal at the Eur...
# 4                                                 na
# 5                                                 na
# 6  Listed in Olympians Who Won a Medal at the Med...
# 7                                                 na

# %%
female_df = pd.read_csv('Olympic_Athlete_Bio.csv', usecols=['name', 'sex', 'country'])
female_df = female_df[female_df['sex'] == 'Female']
female_df.head(8)
# Out:
#                       name     sex             country
# 2      Nathalie Wunderlich  Female         Switzerland
# 8               Taeko Kubo  Female               Japan
# 13      Dannette Leininger  Female       United States
# 14  Nanna Skodborg Merrald  Female             Denmark
# 16          Hannah Afriyie  Female               Ghana
# 17           Lee Myung-Hwa  Female   Republic of Korea
# 20     Kaitinano Mwemweata  Female            Kiribati
# 22     Lyudmila Popovskaya  Female        Soviet Union

# %%
df = athlete_df.merge(female_df, on='name').sort_values('year')
len(df.index)
df.head(8)
# Out:
#                     edition                          name  athlete_id   medal  \
# 18151  1896 Summer Olympics               Stamata Revithi     1202145      na
# 18152  1896 Summer Olympics                     Melpomene     1202146      na
# 62656  1900 Summer Olympics                   Mary Abbott       18139      na
# 34693  1900 Summer Olympics         Lucile, Baroness Fain       17844      na
# 34692  1900 Summer Olympics  Madeleine Fournier-Sarlovèze       17845      na
# 34691  1900 Summer Olympics                 Ellen Ridgway       18194      na
# 34690  1900 Summer Olympics          Mme. Froment-Meurice       17846      na
# 34689  1900 Summer Olympics                   Abbie Pratt       18191  Bronze
#
#        year  season     sex         country
# 18151  1896  Summer  Female          Greece
# 18152  1896  Summer  Female          Greece
# 62656  1900  Summer  Female   United States
# 34693  1900  Summer  Female          France
# 34692  1900  Summer  Female          France
# 34691  1900  Summer  Female          France
# 34690  1900  Summer  Female          France
# 34689  1900  Summer  Female          France

# %%
appearances = df.groupby(['year', 'country']).size().reset_index(name='country_appearances')
df = df.merge(appearances, on=['year', 'country'])
df
# Out:
#                     edition                 name  athlete_id   medal  year  \
# 0      1896 Summer Olympics      Stamata Revithi     1202145      na  1896
# 1      1896 Summer Olympics            Melpomene     1202146      na  1896
# 2      1900 Summer Olympics          Mary Abbott       18139      na  1900
# 3      1900 Summer Olympics      Margaret Abbott       18138    Gold  1900
# 4      1900 Summer Olympics         Marion Jones        2736  Bronze  1900
# ...                     ...                  ...         ...     ...   ...
# 67173  2020 Summer Olympics      Jeanne Boutbien      146513      na  2020
# 67174  2020 Summer Olympics  Ndeye Binta Diongue      146511      na  2020
# 67175  2020 Summer Olympics         Chiara Costa      146512      na  2020
# 67176  2020 Summer Olympics            Mary Lifu      146571      na  2020
# 67177  2020 Summer Olympics       Sharon Firisua      131691      na  2020
#
#        season     sex           country  country_appearances
# 0      Summer  Female            Greece                    2
# 1      Summer  Female            Greece                    2
# 2      Summer  Female     United States                   15
# 3      Summer  Female     United States                   15
# 4      Summer  Female     United States                   15
# ...       ...     ...               ...                  ...
# 67173  Summer  Female           Senegal                    3
# 67174  Summer  Female           Senegal                    3
# 67175  Summer  Female           Senegal                    3
# 67176  Summer  Female   Solomon Islands                    2
# 67177  Summer  Female   Solomon Islands                    2
#
# [67178 rows x 9 columns]

# %%
#now we need to show only the women who received a medal 
medal = df['medal'].notna()
medal.head(8)
#len(medal.index)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: medal, dtype: bool

# %%
df = df[ df['medal'] !='na']
df.head(8)
# Out:
#                  edition             name  athlete_id   medal  year  season  \
# 3   1900 Summer Olympics  Margaret Abbott       18138    Gold  1900  Summer
# 4   1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 5   1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 8   1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 9   1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 10  1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 13  1900 Summer Olympics     Marion Jones        2736  Bronze  1900  Summer
# 21  1900 Summer Olympics      Abbie Pratt       18191  Bronze  1900  Summer
#
#        sex         country  country_appearances
# 3   Female   United States                   15
# 4   Female   United States                   15
# 5   Female   United States                   15
# 8   Female   United States                   15
# 9   Female   United States                   15
# 10  Female   United States                   15
# 13  Female   United States                   15
# 21  Female          France                   31

# %%
df.to_csv('women-summer-medal.csv')

# %%
def powspace(start, stop, power, num):
    '''
    start: first endpoint of resulting array
    stop: last endpoint of resulting array
    power: power to use when spacing out points in array
    num: number of points in resulting array
    '''
    start = np.power(start, 1/float(power))
    stop = np.power(stop, 1/float(power))
    return np.power(np.linspace(start, stop, num=num), power)

# %%
colorbar_range = df['country_appearances'].min(), df['country_appearances'].max()

# Pick some thematic color scheme
colors = px.colors.sequential.YlOrBr if season == 'Summer' else px.colors.sequential.OrRd

colormap_vals = powspace(start=0, stop=1, power=3, num=len(colors) - 1)
colormap_vals = [(0, colors[0]), *[(colormap_vals[i], colors[i + 1]) for i in range(len(colormap_vals))]]

# %%
fig = px.choropleth(
    df,
    locations="country",
    locationmode='country names',
    color='country_appearances',
    projection='natural earth',
    animation_frame='year',
    title=f'Women {season} Olympics Medals, 1900-2020',
    color_continuous_scale=colormap_vals,
    range_color=colorbar_range)

fig.show()
# Out:
# <div>                            <div id="2afeb36e-5053-49fa-bfc6-4d5ca1ec852a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2afeb36e-5053-49fa-bfc6-4d5ca1ec852a")) {                    Plotly.newPlot(                        "2afeb36e-5053-49fa-bfc6-4d5ca1ec852a",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"year=1900<br>country=%{location}<br>country_appearances=%{z}<extra></extra>","locationmode":"country names","locations":[" United States"," United States"," United States"," United States"," United States"," United States"," United States"," France"," France"," France"," France"," Switzerland"," Switzerland"," Switzerland"," Great Britain"," Great Britain"," Bohemia"," Bohemia"," Bohemia"],"name":"","z":[15,15,15,15,15,15,15,31,31,31,31,4,4,4,5,5,3,3,3],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# # sns.set(rc={"fig.figsize":(8, 4)})
# fig.show()

# %%
fig.write_html("summer_medals_women.html")
